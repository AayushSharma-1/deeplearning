# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
path = input("Enter Path of csv")
df = pd.read_csv(path)
user_links = df['user_links'].to_list()
video_links = df['links'].to_list()


followers = []
following = []

no_of_links = int(input("Enter the number of links to scrape --------> it should be less than the size of csv file"))

print("<--------------------Scraping------------------------->")

for i in user_links[:no_of_links]:
    response = requests.get(i)
    if response.status_code == 200:

        soup = BeautifulSoup(response.content, 'html.parser')
        
        if len(soup.find_all('strong', attrs = {'data-e2e':"followers-count"}))!= 0:
            followers.append(soup.find_all('strong', attrs = {'data-e2e':"followers-count"}))
        else:
            followers.append('<strong>nil</strong>')
        if len(soup.find_all('strong', attrs = {'data-e2e':"following-count"}))!= 0:
            following.append(soup.find_all('strong', attrs = {'data-e2e':"following-count"}))
        else:
            following.append('<strong>nil</strong>')
            
        
        
    else:
        followers.append('<strong>no-response</strong>')
        following.append('<strong>no-response</strong>')
        
print("<----------------------Done-------------------->")
print("<---------------Creating DataFrame------------->")
        
followers_count = []
following_count = []
for item1,item2 in zip(followers, following):
    soup1 = BeautifulSoup(str(item1), 'html.parser')
    soup2 = BeautifulSoup(str(item2), 'html.parser')
    
    strong_tags1 = soup1.find_all('strong')
    strong_tags2 = soup2.find_all('strong')
    
    for item1, item2 in zip(strong_tags1, strong_tags2):
        followers_count.append(item1.get_text())
        following_count.append(item2.get_text())
        
data = { 'profile_links': user_links[:no_of_links],
         'video_links' :  video_links[:no_of_links],
         'followers' : followers_count,
         'following' : following_count   
}
df2 = pd.DataFrame(data)
df2
# Out:
# Enter Path of csvC:\Users\aayus\Downloads\tiktok (1).csv
# Enter the number of links to scrape --------> it should be less than the size of csv file15
# <--------------------Scraping------------------------->
# <----------------------Done-------------------->
# <---------------Creating DataFrame------------->
#                                        profile_links  \
# 0                https://www.tiktok.com/@jainfellain
# 1                   https://www.tiktok.com/@nasdaily
# 2                 https://www.tiktok.com/@doctorsood
# 3               https://www.tiktok.com/@bunchojuncos
# 4             https://www.tiktok.com/@__destinylanae
# 5                 https://www.tiktok.com/@notarinozu
# 6            https://www.tiktok.com/@youthgorchrist1
# 7             https://www.tiktok.com/@ittybitty.zy3x
# 8               https://www.tiktok.com/@secrettc4mmy
# 9                 https://www.tiktok.com/@stepplabbu
# 10               https://www.tiktok.com/@marypatross
# 11  https://www.tiktok.com/@providingforthecommunity
# 12            https://www.tiktok.com/@bendingbarbels
# 13            https://www.tiktok.com/@selatiresearch
# 14                https://www.tiktok.com/@manoontjes
#
#                                           video_links followers following
# 0   https://www.tiktok.com/@jainfellain/video/7244...     47.7K       205
# 1   https://www.tiktok.com/@nasdaily/video/7233760...      7.1M         9
# 2   https://www.tiktok.com/@doctorsood/video/72724...        2M       311
# 3   https://www.tiktok.com/@bunchojuncos/video/724...      1518        12
# 4   https://www.tiktok.com/@__destinylanae/video/7...    209.1K        82
# 5   https://www.tiktok.com/@notarinozu/video/72681...       338       564
# 6   https://www.tiktok.com/@youthgorchrist1/video/...     87.9K        29
# 7   https://www.tiktok.com/@ittybitty.zy3x/video/7...      1413       162
# 8   https://www.tiktok.com/@secrettc4mmy/video/726...      1109        10
# 9   https://www.tiktok.com/@stepplabbu/video/72713...       294        11
# 10  https://www.tiktok.com/@marypatross/video/7289...      7229       120
# 11  https://www.tiktok.com/@providingforthecommuni...    987.5K       109
# 12  https://www.tiktok.com/@bendingbarbels/video/7...      5185        90
# 13  https://www.tiktok.com/@selatiresearch/video/7...     29.4K        53
# 14  https://www.tiktok.com/@manoontjes/video/72787...     76.4K        19

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
path = input("Enter Path of csv")
df = pd.read_excel(path)
user_links = df['user_links'].to_list()
video_links = df['links'].to_list()
# Out:
# Enter Path of csvC:\Users\aayus\Downloads\Thesis scraping (2).xlsx

# %%
followers = []
no_of_links = int(input("Enter the number of links to scrape --------> it should be less than the size of csv file"))

print("<--------------------Scraping------------------------->")

for i in user_links[:no_of_links]:
    response = requests.get(i)
    if response.status_code == 200:

        soup = BeautifulSoup(response.content, 'html.parser')
        
        if len(soup.find_all('strong', attrs = {'data-e2e':"followers-count"}))!= 0:
            followers.append(soup.find_all('strong', attrs = {'data-e2e':"followers-count"}))
        else:
            followers.append('<strong>nil</strong>')
#         if len(soup.find_all('strong', attrs = {'data-e2e':"following-count"}))!= 0:
#             following.append(soup.find_all('strong', attrs = {'data-e2e':"following-count"}))
#         else:
#             following.append('<strong>nil</strong>')
            
        
        
    else:
        followers.append('<strong>no-response</strong>')
#         following.append('<strong>no-response</strong>')
        
print("<----------------------Done-------------------->")
print("<---------------Creating DataFrame------------->")
# Out:
# Enter the number of links to scrape --------> it should be less than the size of csv file366
# <--------------------Scraping------------------------->
# <----------------------Done-------------------->
# <---------------Creating DataFrame------------->

# %%
followers_count = []
# following_count = []
for item1 in (followers):
    soup1 = BeautifulSoup(str(item1), 'html.parser')
#     soup2 = BeautifulSoup(str(item2), 'html.parser')
    
    strong_tags1 = soup1.find_all('strong')
#     strong_tags2 = soup2.find_all('strong')
    
    for item1 in (strong_tags1):
        followers_count.append(item1.get_text())
#         following_count.append(item2.get_text())
        
data = { 'profile_links': user_links[:no_of_links],
         'video_links' :  video_links[:no_of_links],
         'followers' : followers_count
}
df2 = pd.DataFrame(data)
df2
# Out:
#                                      profile_links  \
# 0                https://www.tiktok.com/@placitech
# 1          https://www.tiktok.com/@tamuproductionz
# 2    https://www.tiktok.com/@the.potential.dropout
# 3               https://www.tiktok.com/@minenezuzu
# 4              https://www.tiktok.com/@saayaparikh
# ..                                             ...
# 361           https://www.tiktok.com/@mackswetnich
# 362           https://www.tiktok.com/@bretrealllao
# 363  https://www.tiktok.com/@the.potential.dropout
# 364  https://www.tiktok.com/@the.potential.dropout
# 365              https://www.tiktok.com/@engr.tala
#
#                                            video_links followers
# 0    https://www.tiktok.com/@placitech/video/728062...    246.5K
# 1    https://www.tiktok.com/@tamuproductionz/video/...       nil
# 2    https://www.tiktok.com/@the.potential.dropout/...       nil
# 3    https://www.tiktok.com/@minenezuzu/video/71929...       nil
# 4    https://www.tiktok.com/@saayaparikh/video/7293...      9599
# ..                                                 ...       ...
# 361  https://www.tiktok.com/@mackswetnich/video/681...       nil
# 362  https://www.tiktok.com/@bretrealllao/video/729...       nil
# 363  https://www.tiktok.com/@the.potential.dropout/...       nil
# 364  https://www.tiktok.com/@the.potential.dropout/...       nil
# 365  https://www.tiktok.com/@engr.tala/video/727349...       nil
#
# [366 rows x 3 columns]

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

path = input("Enter Path of csv")
df = pd.read_excel(path)
user_links = df['user_links'].to_list()
video_links = df['links'].to_list()
usernames = df['usernames'].to_list()

followers = []
no_of_links = int(input("Enter the number of links to scrape --------> it should be less than the size of csv file"))

print("<--------------------Scraping------------------------->")

for i in user_links[:no_of_links]:
    response = requests.get(i)
    if response.status_code == 200:

        soup = BeautifulSoup(response.content, 'html.parser')

        if len(soup.find_all('strong', attrs={'data-e2e': "followers-count"})) != 0:
            followers.append(soup.find_all('strong', attrs={'data-e2e': "followers-count"}))
        else:
            followers.append('<strong>nil</strong>')



    else:
        followers.append('<strong>no-response</strong>')


print("<----------------------Done-------------------->")
print("<---------------Creating DataFrame------------->")

followers_count = []
following_count = []
title = []
email = []

for item1 in (followers):
    soup1 = BeautifulSoup(str(item1), 'html.parser')

    strong_tags1 = soup1.find_all('strong')

    for item1 in (strong_tags1):
        followers_count.append(item1.get_text())

data = {'profile_links': user_links[:no_of_links],
        'usernames':usernames[:no_of_links],
        'followers': followers_count,
        'other_links': video_links[:no_of_links]
        }
df2 = pd.DataFrame(data)

df2
# Out:
# Enter Path of csvC:\Users\aayus\Downloads\Thesis scraping (2).xlsx
# Enter the number of links to scrape --------> it should be less than the size of csv file100
# <--------------------Scraping------------------------->
# <----------------------Done-------------------->
# <---------------Creating DataFrame------------->
#                                  profile_links           usernames followers  \
# 0     https://www.tiktok.com/@zak.the.engineer    zak.the.engineer     27.4K
# 1           https://www.tiktok.com/@successgps          successgps      8980
# 2           https://www.tiktok.com/@annaxsitar          annaxsitar     12.1M
# 3   https://www.tiktok.com/@studentengineering  studentengineering      5686
# 4         https://www.tiktok.com/@abby_maltese        abby_maltese    153.9K
# ..                                         ...                 ...       ...
# 95     https://www.tiktok.com/@maridelicatepov     maridelicatepov       nil
# 96        https://www.tiktok.com/@_jackierids_        _jackierids_       nil
# 97             https://www.tiktok.com/@alyy_gr             alyy_gr       nil
# 98      https://www.tiktok.com/@jasminesawaged      jasminesawaged       nil
# 99     https://www.tiktok.com/@andreww_mckenna     andreww_mckenna       nil
#
#                                           other_links
# 0   https://www.tiktok.com/@zak.the.engineer/video...
# 1   https://www.tiktok.com/@successgps/video/72184...
# 2   https://www.tiktok.com/@annaxsitar/video/69846...
# 3   https://www.tiktok.com/@studentengineering/vid...
# 4   https://www.tiktok.com/@abby_maltese/video/726...
# ..                                                ...
# 95  https://www.tiktok.com/@maridelicatepov/video/...
# 96  https://www.tiktok.com/@_jackierids_/video/727...
# 97  https://www.tiktok.com/@alyy_gr/video/72634447...
# 98  https://www.tiktok.com/@jasminesawaged/video/7...
# 99  https://www.tiktok.com/@andreww_mckenna/video/...
#
# [100 rows x 4 columns]

# %%
df2.to_csv('thesis_ans_only100(2).csv')
